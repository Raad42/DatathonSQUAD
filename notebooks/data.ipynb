# %%
import pandas as pd 
import os 

filepath = os.path.join('..', 'data', 'processed', 'cleaned_train_data_logScaled.csv')

df = pd.read_csv(filepath)

# %%
df = df.drop('X18', axis=1)

# %%
df
# Out:
#             ID       X1  X2     X3  X4  X5  X6        X7  X8  X10  ...  \
# 0       256039   3600.0   0   7.37   1   0   1   62004.0   0    5  ...
# 1       176486  12000.0   1  16.49   4   6   1  143000.0   0    1  ...
# 2       392670   8500.0   1  11.49   0   1   1   27000.0   0    3  ...
# 3        46168   3725.0   0  10.99   0  11   0   14916.0   2    1  ...
# 4       313821  28000.0   0  15.41   4   0   0  100000.0   1    1  ...
# ...        ...      ...  ..    ...  ..  ..  ..       ...  ..  ...  ...
# 316819  149632  24000.0   0   7.90   1   9   0  128000.0   2    2  ...
# 316820  324071   8000.0   0  12.12   0  11   0   35000.0   2    1  ...
# 316821  164619  15000.0   0  18.55   4   9   1   88400.0   2    1  ...
# 316822  183340  10800.0   1  24.99   5   1   2   36000.0   2    1  ...
# 316823  152215   2200.0   0  20.20   4   5   0   16000.0   0    7  ...
#
#              X12  X13        X14   X15   X16  X17      X19  Y  X9_Month  \
# ...

# %%
df.to_csv(filepath)

# %%
filepath2 = os.path.join('..', 'data', 'processed', 'cleaned_test_data_logScaled.csv')

df2 = pd.read_csv(filepath2)

# %%
df2
# Out:
#            ID       X1  X2     X3  X4  X5  X6       X7  X8  X10  ...  \
# 0      335599  25000.0   0   5.32   1   0   1  90000.0   0    6  ...
# 1      234182  14000.0   0  13.11   0   0   0  85500.0   0    1  ...
# 2      335286   7000.0   0   8.39   0   0   1  77000.0   0    6  ...
# 3      172447   2500.0   0  15.61   2  11   0  14000.0   2    2  ...
# 4      345387   3500.0   0  13.33   2   6   1  83000.0   1    5  ...
# ...       ...      ...  ..    ...  ..  ..  ..      ...  ..  ...  ...
# 71601  391186   8400.0   0   8.18   0   1   1  53000.0   0    1  ...
# 71602  306219  21000.0   1  16.59   4   0   1  95000.0   1    1  ...
# 71603  133782   6500.0   0  10.49   0   4   0  67000.0   2    1  ...
# 71604  136738  15000.0   0  22.74   3   0   0  97000.0   1    3  ...
# 71605  384732  21125.0   0  14.09   0   2   0  48500.0   2    1  ...
#
#             X12  X13        X14   X15   X16  X17  X18  X19  X9_Month  X9_Year
# ...

# %%
df2 = df2.drop('X18', axis=1)

# %%
df2.to_csv(filepath2)

# %%
filepath3 = os.path.join('..', 'data', 'processed', 'cleaned_test_data.csv')

df3 = pd.read_csv(filepath3)

# %%
df3 = df3.drop('X18', axis=1)

# %%
df3.to_csv(filepath3)

# %%
filepath4 = os.path.join('..', 'data', 'processed', 'cleaned_train_data.csv')

df4 = pd.read_csv(filepath4)

# %%
df4 = df4.drop('X18', axis=1)

# %%
df4.to_csv(filepath4)
